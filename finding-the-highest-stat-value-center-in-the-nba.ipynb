# %% [markdown]
# Import Stats of All NBA Players from 2021-2022 Season

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/nba-player-stats/2021-2022 NBA Player Stats - Regular.csv', encoding="Windows-1252", delimiter=";")

df.head()
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0   1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  0.595
# 1   2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  0.543
# 2   3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  0.753
# 3   4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  0.625
# 4   5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  0.873
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
#
# [5 rows x 30 columns]

# %% [markdown]
# Select all Centers from dataframe

# %%
cf=df.loc[(df['Pos']=='C')]
cf
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# 9      8      Jarrett Allen   C   23  CLE  56  56  32.3  6.6   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 789  589    Robert Williams   C   24  BOS  61  61  29.6  4.4   6.0  ...
# 797  595     Christian Wood   C   26  HOU  68  67  30.8  6.5  12.9  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %% [markdown]
# Select Centers with 20+ PPG

# %%
cfp=cf.loc[(cf['PTS']>20)]
cfp=cfp[['Player','Age','AST','TRB','STL','BLK','PTS']]
cfp
# Out:
#                  Player  Age  AST   TRB  STL  BLK   PTS
# 160       Anthony Davis   28  3.1   9.9  1.2  2.3  23.2
# 206         Joel Embiid   27  4.2  11.7  1.1  1.5  30.6
# 391        Nikola Joki?   26  7.9  13.8  1.5  0.9  27.1
# 736  Karl-Anthony Towns   26  3.6   9.8  1.0  1.1  24.6

# %% [markdown]
# Plot As Graph

# %%
import matplotlib.pyplot as plt
plt.plot(cfp['Player'],cfp['PTS'])
plt.title('Points per Game Centers')
plt.xlabel('Player')
plt.ylabel('PTS')
for x,y in zip(cfp['Player'],cfp['PTS']):
    label = "{:}".format(x)
    plt.annotate(label,(x,y), textcoords="offset points", xytext=(0,10),ha='center')
ax=plt.gca()
ax.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# Select Centers with 2+ BPG

# %%
cfb=cf.loc[(cf['BLK']>2)]
cfb=cfb[['Player','AST','TRB','STL','BLK','PTS']]
cfb
# Out:
#               Player  AST   TRB  STL  BLK   PTS
# 160    Anthony Davis  3.1   9.9  1.2  2.3  23.2
# 257      Rudy Gobert  1.1  14.7  0.7  2.1  15.6
# 742     Myles Turner  1.0   7.1  0.7  2.8  12.9
# 789  Robert Williams  2.0   9.6  0.9  2.2  10.0

# %% [markdown]
# Plot as Graph

# %%
import matplotlib.pyplot as plt
plt.plot(cfb['Player'],cfb['BLK'])
plt.title('Blocks per Game Centers')
plt.xlabel('Player')
plt.ylabel('BLK')
for x,y in zip(cfb['Player'],cfb['BLK']):
    label = "{:}".format(x)
    plt.annotate(label,(x,y), textcoords="offset points", xytext=(0,10),ha='center')
ax=plt.gca()
ax.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# Select Centers with 3+ APG

# %%
cfa=cf.loc[(cf['AST']>3)]
cfa=cfa[['Player','AST','STL','TRB','BLK','PTS']]
cfa
# Out:
#                  Player  AST  STL   TRB  BLK   PTS
# 1          Steven Adams  3.4  0.9  10.0  0.8   6.9
# 2           Bam Adebayo  3.4  1.4  10.1  0.8  19.1
# 160       Anthony Davis  3.1  1.2   9.9  2.3  23.2
# 206         Joel Embiid  4.2  1.1  11.7  1.5  30.6
# 333          Al Horford  3.4  0.7   7.7  1.3  10.2
# 391        Nikola Joki?  7.9  1.5  13.8  0.9  27.1
# 519         Greg Monroe  4.0  1.0   6.0  1.5   7.3
# 592       Mason Plumlee  3.1  0.8   7.7  0.7   6.5
# 648    Domantas Sabonis  5.0  1.0  12.1  0.5  18.9
# 736  Karl-Anthony Towns  3.6  1.0   9.8  1.1  24.6
# 751      Nikola Vu?evi?  3.2  1.0  11.0  1.0  17.6

# %% [markdown]
# Plot as Graph

# %%
import matplotlib.pyplot as plt
plt.plot(cfa['Player'],cfa['AST'])
plt.title('Assists per Game Centers')
plt.xlabel('Player')
plt.ylabel('AST')
for x,y in zip(cfa['Player'],cfa['AST']):
    label = "{:}".format(x)
    plt.annotate(label,(x,y), textcoords="offset points", xytext=(0,10),ha='center')
ax=plt.gca()
ax.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# Select Centers with 1+ SPG

# %%
cfs=cf.loc[(cf['STL']>1)]
cfs=cfs[['Player','AST','STL','BLK','TRB','PTS']]
cfs
# Out:
#              Player  AST  STL  BLK   TRB   PTS
# 2       Bam Adebayo  3.4  1.4  0.8  10.1  19.1
# 160   Anthony Davis  3.1  1.2  2.3   9.9  23.2
# 192  Andre Drummond  1.8  1.1  0.9   9.3   7.9
# 193  Andre Drummond  2.0  1.1  0.9   8.8   6.1
# 206     Joel Embiid  4.2  1.1  1.5  11.7  30.6
# 391    Nikola Joki?  7.9  1.5  0.9  13.8  27.1
# 554    Nerlens Noel  0.9  1.2  1.2   5.6   3.4
# 557    Jusuf Nurki?  2.8  1.1  0.6  11.1  15.0

# %% [markdown]
# Plot as Graph

# %%
import matplotlib.pyplot as plt
plt.plot(cfs['Player'],cfs['STL'])
plt.title('Steals per Game Centers')
plt.xlabel('Player')
plt.ylabel('STL')
for x,y in zip(cfs['Player'],cfs['STL']):
    label = "{:}".format(x)
    plt.annotate(label,(x,y), textcoords="offset points", xytext=(0,10),ha='center')
ax=plt.gca()
ax.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# Select Centers with 8+ RBG

# %%
cfr=cf.loc[(cf['TRB']>8)]
cfr=cfr[['Player','AST','TRB','STL','BLK','PTS']]
cfr
# Out:
#                  Player  AST   TRB  STL  BLK   PTS
# 1          Steven Adams  3.4  10.0  0.9  0.8   6.9
# 2           Bam Adebayo  3.4  10.1  1.4  0.8  19.1
# 9         Jarrett Allen  1.6  10.8  0.8  1.3  16.1
# 27        Deandre Ayton  1.4  10.2  0.7  0.7  17.2
# 34             Mo Bamba  1.2   8.1  0.5  1.7  10.6
# 112        Clint Capela  1.2  11.9  0.7  1.3  11.1
# 119  Wendell Carter Jr.  2.8  10.5  0.6  0.7  15.0
# 160       Anthony Davis  3.1   9.9  1.2  2.3  23.2
# 192      Andre Drummond  1.8   9.3  1.1  0.9   7.9
# 193      Andre Drummond  2.0   8.8  1.1  0.9   6.1
# 194      Andre Drummond  1.4  10.3  0.9  1.0  11.8
# 206         Joel Embiid  4.2  11.7  1.1  1.5  30.6
# 213        Drew Eubanks  1.6   8.5  0.8  0.5  14.5
# 257         Rudy Gobert  1.1  14.7  0.7  2.1  15.6
# 391        Nikola Joki?  7.9  13.8  1.5  0.9  27.1
# 557        Jusuf Nurki?  2.8  11.1  1.1  0.6  15.0
# 593        Jakob Poeltl  2.8   9.3  0.7  1.7  13.5
# ...

# %% [markdown]
# Plot as Graph

# %%
import matplotlib.pyplot as plt
plt.plot(cfr['Player'],cfr['TRB'])
plt.title('Rebounds per Game Centers')
plt.xlabel('Player')
plt.ylabel('Rebounds')
for x,y in zip(cfr['Player'],cfr['TRB']):
    label = "{:}".format(x)
    plt.annotate(label,(x,y), textcoords="offset points", xytext=(0,10),ha='center')
ax=plt.gca()
ax.axes.xaxis.set_ticklabels([])
plt.show()

# %% [markdown]
# Finding common

# %%
import copy
dfs_array = [cfa, cfb,cfr,cfp,cfs]
if len(dfs_array) <= 1:
    dfs_array
dfs = copy.copy(dfs_array)
length = len(dfs) 
while length > 1:
    df1 = dfs.pop()
    df2 = dfs.pop()
    df0 = df1.loc[ df1['Player'].isin( df2['Player'].values ) ]
    dfs.insert(0,df0)
    length = len(dfs)
dfs
# Out:
# [            Player  AST  TRB  STL  BLK   PTS
#  160  Anthony Davis  3.1  9.9  1.2  2.3  23.2]
